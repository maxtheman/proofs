# %% [raw]
# ---
# description: This is a proofs validator to help students and hobbyists do mathematical
#   thinking and problem solving.
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(not_equals)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### not_equals
#
# >      not_equals (lhs:Union[sympy.core.expr.Expr,sympy.core.basic.Basic],
# >                  rhs:Union[sympy.core.expr.Expr,sympy.core.basic.Basic])

# %%
#| echo: false
#| output: asis
show_doc(equals)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### equals
#
# >      equals (lhs:sympy.core.expr.Expr, rhs:sympy.core.expr.Expr)

# %%
#| echo: false
#| output: asis
show_doc(equation)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### equation
#
# >      equation (expr:str)

# %%
#| echo: false
#| output: asis
show_doc(constant)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### constant
#
# >      constant (value:Union[int,float])

# %%
#| echo: false
#| output: asis
show_doc(variable)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### variable
#
# >      variable (name:str)

# %%
#| echo: false
#| output: asis
show_doc(make_examples)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L47){target="_blank" style="float:right; font-size:smaller"}
#
# ### make_examples
#
# >      make_examples (domain:str, N:int, equation:str)
#
# For a given domain and equation, select N examples and generate a list of N input-output pairs.
# Currently, the domain can be either 'real' or 'integer', and one variable is assumed.

# %%
make_examples('real', 10, 'x**2')
# Out:
# [(-13, 169),
#  (-29, 841),
#  (-61, 3721),
#  (-45, 2025),
#  (95, 9025),
#  (-14, 196),
#  (-74, 5476),
#  (-77, 5929),
#  (-3, 9),
#  (-76, 5776)]

# %%
#| echo: false
#| output: asis
show_doc(prove)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L68){target="_blank" style="float:right; font-size:smaller"}
#
# ### prove
#
# >      prove (goal:Union[sympy.core.relational.Equality,sympy.core.relational.Un
# >             equality,sympy.core.relational.Relational], proof_func:Callable[..
# >             .,Union[sympy.core.relational.Equality,sympy.core.relational.Unequ
# >             ality,sympy.core.relational.Relational]], *args)

# %%
#| echo: false
#| output: asis
show_doc(contradiction_proof)
# Out:
# ---
#
# [source](https://github.com/maxtheman/proofs/blob/main/proofs/core.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### contradiction_proof
#
# >      contradiction_proof (proof)

# %% [markdown]
# Here's how to use a contradiction goal.

# %%
# Start by defining your domain
arbitrary_x = variable("x")
expression = arbitrary_x + 1

# Then define your goal
contradiction_goal = not_equals(expression, arbitrary_x)

@contradiction_proof
def proof_of_x_plus_one(x):
    # Given x, Assume x + 1 = x is true for arbitrary_x
    assumed_eq = equals(x + 1, x)

    # Calculate x + 1
    next = x + 1

    # Observing x + 1 $\neq$ x, we have reached a contradiction
    return not_equals(next, assumed_eq.rhs)
# Out:
# $x$
# $x + 1 \neq x$

# %%
prove(contradiction_goal, proof_of_x_plus_one, arbitrary_x)
# Out:
# Given x, Assume x + 1 = x is true for arbitrary_x
# $x + 1 = x$
# Calculate x + 1
# Observing x + 1 $\neq$ x, we have reached a contradiction
# $x + 1 \neq x$
# $x + 1 = x$
# $x + 1 \neq x$
# $$\text \quad x + 1 \neq x \quad Q.E.D.$$
# True
